# %% [markdown]
# # 3-9-2019

# %% [markdown]
# ## List
#  * List is a collection of items

# %% [markdown]
#    * list declaration

# %%
a=list()
b=[]

# %%
print('a   type  ',type(a))
print('b   type  ',type(b))
# Out:
# a   type   <class 'list'>
# b   type   <class 'list'>

# %%
len(a)
# Out:
# 0

# %%
a=[1,2,3,5,4]

# %%
a
# Out:
# [1, 2, 3, 5, 4]

# %%
len(a)
# Out:
# 5

# %% [markdown]
# # List method

# %% [markdown]
#    * ### APPEND

# %%
b
# Out:
# []

# %%
b.append(11)

# %%
b
# Out:
# [11]

# %%
b.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-de243635e870> in <module>
# ----> 1 b.append()
#
# TypeError: append() takes exactly one argument (0 given)

# %%
b=['ch','vyshu']

# %%
type(b)
# Out:
# list

# %%
type(b[0])
# Out:
# str

# %%
a.append(b)

# %%
a
# Out:
# [1, 2, 3, 5, 4, ['ch', 'vyshu']]

# %%
len(a)
# Out:
# 6

# %%
a[-1]
# Out:
# ['ch', 'vyshu']

# %%
a[-1][0]
# Out:
# 'ch'

# %%
a[5][0]
# Out:
# 'ch'

# %%
a[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-84c1e027215d> in <module>
# ----> 1 a[6]
#
# IndexError: list index out of range

# %%
a[]
# Out:
#   File "<ipython-input-32-f195c1342970>", line 1
#     a[]
#       ^
# SyntaxError: invalid syntax

# %%
a[-1][0]='chalapati'

# %%
a
# Out:
# [1, 2, 3, 5, 4, ['chalapati', 'vyshu']]

# %%
if type(a==list):
    print('fgd')
else:
    print('fdg')
# Out:
# fgd

# %%
a[5].append('hello')

# %%
a
# Out:
# [1, 2, 3, 5, 4, ['chalapati', 'vyshu', 'hello']]

# %% [markdown]
#    * ## EXTEND

# %%
a=[1,2,3]
b=[4,5]
a,b
# Out:
# ([1, 2, 3], [4, 5])

# %%
a.extend(b)
a,b
# Out:
# ([1, 2, 3, 4, 5], [4, 5])

# %% [markdown]
#    * ## count

# %%
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 4, 5]

# %%
a.count(40) #not available
# Out:
# 0

# %%
a.count(4)
# Out:
# 2

# %%
[10,[10,20],[10]].count(20)
# Out:
# 0

# %%
[10,[10,20],[10]].count(10)
# Out:
# 1

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# # Index

# %%
a.index(4)
# Out:
# 3

# %%
a.index(477)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-f352182670b0> in <module>
# ----> 1 a.index(477)
#
# ValueError: 477 is not in list

# %%
s=[]
s=[1,2,3].clear()

# %% [markdown]
# ## copy

# %%
a=[1,2]
b=a
a,b
# Out:
# ([1, 2], [1, 2])

# %%
a.append(5)

# %%
a,b
# Out:
# ([1, 2, 5], [1, 2, 5])

# %%
b=a.copy()

# %%
a.append(51)

# %%
a,b
# Out:
# ([1, 2, 5, 51], [1, 2, 5])

# %% [markdown]
# # insert(index,item)

# %%
a=[1, 2, 5, 51]

# %%
a.insert(2,4)
a
# Out:
# [1, 2, 4, 5, 51]

# %%
a.insert(2,3)
a
# Out:
# [1, 2, 3, 4, 5, 51]

# %%
a.insert(20,3)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 51, 3]

# %% [markdown]
# # Pop

# %%
a.pop()
# Out:
# 3

# %%
a
# Out:
# [1, 2, 3, 4, 5, 51]

# %%
a.pop(-1)
# Out:
# 51

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.pop(234)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-139-c4aebe2feb70> in <module>
# ----> 1 a.pop(234)
#
# IndexError: pop index out of range

# %%
a.pop(0)
# Out:
# 1

# %%
a
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# # remove

# %%
a=[2, 3, 4, 5,3]

# %%
a.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-6af94287cfde> in <module>
# ----> 1 a.remove()
#
# TypeError: remove() takes exactly one argument (0 given)

# %%
a.remove(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-ae1fd24e9d23> in <module>
# ----> 1 a.remove(0)
#
# ValueError: list.remove(x): x not in list

# %%
a.remove(3)

# %%
a
# Out:
# [2, 4, 5, 3]

# %% [markdown]
# # sort

# %%
a.sort()

# %%
a
# Out:
# [2, 3, 4, 5]

# %%
a.reverse()
a
# Out:
# [5, 4, 3, 2]

# %%
a.sort()
a
# Out:
# [2, 3, 4, 5]

# %%
a.sort(reverse=True)
a
# Out:
# [5, 4, 3, 2]

# %%
a.sort()

# %%
a
# Out:
# [2, 3, 4, 5]

# %%
min(a),max(a)
# Out:
# (2, 5)

# %% [markdown]
# # slicing

# %%
a=[1,2,3,4,5,6,7,8,9]
a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
a[0:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
a[::2]
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# # Tuples
#    * it is immutable(can't be change)

# %%
a=tuple()
b=()
type(a),type(b)
# Out:
# (tuple, tuple)

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
len(a)
# Out:
# 0

# %%
a=(10,20,30,10,10,200,'hai','hai','df')

# %%
len(a)
# Out:
# 9

# %%
a[1]=22
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-5fd685aa007e> in <module>
# ----> 1 a[1]=22
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # count(item)

# %%
a.count(10)
# Out:
# 3

# %%
a[1]
# Out:
# 20

# %%
a.count('hai')
# Out:
# 2

# %%
a.count(4)
# Out:
# 0

# %% [markdown]
# # index(item)

# %%
a.index(10)
# Out:
# 0

# %%
a.index('hai')
# Out:
# 6

# %%
a.index(44)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-de9948785b2f> in <module>
# ----> 1 a.index(44)
#
# ValueError: tuple.index(x): x not in tuple

# %%
b=(10,20,30)
min(b),max(b),sum(b)
# Out:
# (10, 30, 60)

# %%
a=(1,2,3,4,5,6,7,8,9)

# %%
a[3:0:-1]
# Out:
# (4, 3, 2)

# %%
a[1:4][::-1]
# Out:
# (4, 3, 2)

# %% [markdown]
# # strings

# %%
a=" fjdgh"

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
a="vyshnavi"
a.capitalize()
# Out:
# 'Vyshnavi'

# %%
a='VYSH5naVI'
a.casefold()
# Out:
# 'vysh5navi'

# %%
a.center(50)
# Out:
# '                    VYSH5naVI                     '

# %%
a.count('V')
# Out:
# 2

# %%
10.isdigit()
# Out:
#   File "<ipython-input-220-7296276e1d8a>", line 1
#     10.isdigit()
#              ^
# SyntaxError: invalid syntax

# %%
'10'.isdigit()
# Out:
# True

# %%
'10s'.isdigit()
# Out:
# False

# %%
txt = "My name is Ståle"

txt.encode()
# Out:
# b'My name is St\xc3\xa5le'

# %% [markdown]
# # JOINS

# %%
n=['a','b','c','v']
''.join(n)
# Out:
# 'abcv'

# %%
n=['a','b',6,'c','v']
''.join(n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-231-159db5bba0ef> in <module>
#       1 n=['a','b',6,'c','v']
# ----> 2 ''.join(n)
#
# TypeError: sequence item 2: expected str instance, int found

# %% [markdown]
# # Dictinory

# %%
d=dict()
type(d)
# Out:
# dict

# %%
x={}
type(x)
# Out:
# dict
